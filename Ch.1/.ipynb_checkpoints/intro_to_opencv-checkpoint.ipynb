# %% [markdown]
# ## A theoretical introduction to the OpenCV library

# %% [markdown]
# **OpenCV** is a programming library with real-time computer vision capabilities and it is free for both academic and commercial use (BSD license).

# %% [markdown]
# **OpenCV modules**
#
# OpenCV (since version 2) is divided into several modules, where each module can be understood, in general, as being dedicated to one group of computer vision problems. This division can be seen in the next diagram, where the main modules are shown:
#
# <img src='data:image/png;base64,...'>

# %% [markdown]
# ### OpenCV modules are shortly described here:

# %% [markdown]
# **1. core:** Core functionality. Core functionality is a module defining basic data structures and also basic functions used by all other modules in the library.

# %% [markdown]
# **2. imgproc:** Image processing. An image-processing module that includes image filtering, geometrical image transformations, color space conversion, and histograms.

# %% [markdown]
# **3. imgcodecs:** Image codecs. Image file reading and writing.

# %% [markdown]
# **4. videoio:** Video I/O. An interface to video capturing and video codecs.

# %% [markdown]
# **5. highgui:** High-level GUI. An interface to UI capabilities. It provides an interface to easily do the following:
#
# * Create and manipulate windows that can display/show images
# * Add trackbars to the windows, keyboard commands, and handle mouse events

# %% [markdown]
# **6. video:** Video analysis. A video-analysis module including background subtraction, motion estimation, and object-tracking algorithms.

# %% [markdown]
# **7. calib3d:** Camera calibration and 3D reconstruction. Camera calibration and 3D reconstruction covering basic multiple-view geometry algorithms, stereo correspondence algorithms, object pose estimation, both single and stereo camera calibration, and also 3D reconstruction.

# %% [markdown]
# **8. features2d:** 2D features framework. This module includes feature detectors, descriptors, and descriptor matchers.

# %% [markdown]
# **9. objdetect:** Object detection. Detection of objects and instances of predefined classes (for example, faces, eyes, people, and cars).

# %% [markdown]
# **10. dnn:** Deep neural network (DNN) module. This module contains the following:
#
# * API for new layers creation
# * Set of built useful layers
# * API to construct and modify neural networks from layers
# * Functionality for loading serialized networks models from different deep learning frameworks

# %% [markdown]
# **11. ml: Machine learning.** The Machine Learning Library (MLL) is a set of classes and methods that can be used for classification, regression, and clustering purposes.

# %% [markdown]
# **12. flann:** Clustering and search in multi-dimensional spaces. `Fast Library for Approximate Nearest Neighbors (FLANN)` is a collection of algorithms that are highly suited for fast nearest-neighbor searches.

# %% [markdown]
# **13. photo: Computational photography.** This module provides some functions for computational photography.

# %% [markdown]
# **14. stitching: Images stitching.** This module implements a stitching pipeline that performs automatic panoramic image stitching.

# %% [markdown]
# **15. shape:** Shape distance and matching. Shape distance and matching module that can be used for shape matching, retrieval, or comparison.

# %% [markdown]
# **16. superres:** Super-resolution. This module contains a set of classes and methods that can be used for resolution enhancement.

# %% [markdown]
# **17. videostab:** Video stabilization. This module contains a set of classes and methods for video stabilization.

# %% [markdown]
# **18. viz:** 3D visualizer. This module is used to display widgets that provide several methods to interact with scenes and widgets.

# %% [markdown]
# ## OpenCV applications
#
# OpenCV is being used for a very wide range of applications:

# %% [markdown]
# 1. 2D and 3D feature toolkits
# 2. Street view image stitching
# 3. Egomotion estimation
# 4. Facial-recognition system
# 5. Gesture recognition
# 6. Human-computer interaction
# 7. Mobile robotics
# 8. Motion understanding
# 9. Object identification
# 10. Automated inspection and surveillance
# 11. Segmentation and recognition
# 12. Stereopsis stereo vision – depth perception from two cameras
# 13. Medical image analysis
# 14. Structure from motion
# 15. Motion tracking
# 16. Augmented reality
# 17. Video/image search and retrieval
# 18. Robot and driverless car navigation and control
# 19. Driver drowsiness and distraction detection

# %% [markdown]
# #### Citing OpenCV in your work...
#
# If you are using OpenCV in your research, it is recommended you cite the OpenCV library. This way, other researchers can better understand your proposed algorithms and reproduce your results for better credibility. Additionally, OpenCV will increase repercussion, resulting in a better computer vision library. The BibTex entry for citing OpenCV is shown in the following code:
#
# ```
# @article{opencv_library,
#  author = {Bradski, G.},
#  citeulike-article-id = {2236121},
#  journal = {Dr. Dobb's Journal of Software Tools},
#  keywords = {bibtex-import},
#  posted-at = {2008-01-15 19:21:54},
#  priority = {4},
#  title = {{The OpenCV Library}},
#  year = {2000}
# }
# ```
